# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.xkcd()
plt.bar([0,1],[1e5,1e9])
plt.xlim(-0.5,2.5)
plt.yscale('log')
plt.xticks([0.5,1.5],['OpenWorm','HBP'])
plt.ylabel('Budget ($)')
plt.ylim(1e3,1e10)
plt.figure()
plt.bar([0,1],[5,5])
plt.xlim(-0.5,2.5)
plt.xticks([0.5,1.5],['OpenWorm','HBP'])
plt.ylabel('Papers')
plt.ylim(0,7);
